# %%
import pandas as pd

# %%
# Garante que todas as colunas sejam exibidas
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# %%
df_contratos = pd.read_csv('../data/terceirizados/arquivos_tratados/consolidado_validacao_completo.csv', dtype='str')

# %%
df_contratos.head()
# Out:
#   nr_contrato cd_orgao_siafi                     nm_razao_social  \
# 0   000002019          26273             SULCLEAN SERVICOS LTDA.
# 1   000002023          20411                            XYZ LTDA
# 2   000012011          20411  POLO SEGURANCA ESPECIALIZADA LTDA.
# 3   000012012          20411                   ARE SERVICOS LTDA
# 4   000012012          36212    RM SERVILOS EMPRESARIAIS LTDA-ME
#
#   sg_orgao_sup_tabela_ug cd_ug_gestora  \
# 0               MIN.EDUC        154042
# 1                   MINC        343029
# 2               MINIST.         343002
# 3               MINIST.         343003
# 4               MINISTER        253029
#
#                                      nm_ug_tabela_ug     sg_ug_gestora  \
# 0           UNIVERIDADE FEDERAL DO RIO GRANDE - FURG              FURG
# 1      SUPERINTENDENCIA DO IPHAN NO DISTRITO FEDERAL          IPHAN-DF
# 2                  SUPERINTENDENCIA DO IPHAN NO PARA          IPHAN-PA
# ...

# %%
df_contratos[df_contratos['status_validacao'] == 'Não encontrado']
# Out:
#      nr_contrato cd_orgao_siafi                            nm_razao_social  \
# 0      000002019          26273                    SULCLEAN SERVICOS LTDA.
# 1      000002023          20411                                   XYZ LTDA
# 2      000012011          20411         POLO SEGURANCA ESPECIALIZADA LTDA.
# 3      000012012          20411                          ARE SERVICOS LTDA
# 4      000012012          36212           RM SERVILOS EMPRESARIAIS LTDA-ME
# ...          ...            ...                                        ...
# 3681   000032022          26258    ADSERVI ADMINISTRADORA DE SERVICOS LTDA
# 3682   000032022          26258       TATICO PERSEG SEGURANCA PRIVADA LTDA
# 3683   000032022          26258  TATICO PERSEG SEGURANCA PRIVADA LTDA - ME
# 3684   000032022          26262   VERZZON - ADMINISTRACAO DE SERVICOS LTDA
# 3685   000032022          26262    VERZZON -ADMINISTRACAO DE SERVICOS LTDA
#
#      sg_orgao_sup_tabela_ug cd_ug_gestora  \
# ...

# %%
print(df_contratos[(df_contratos['nr_contrato'] == '000032021') & (df_contratos['cd_orgao_siafi'] == '20404')])
# Out:
#      nr_contrato cd_orgao_siafi            nm_razao_social  \
# 3509   000032021          20404  CONSERVADORA RIOLIMP LTDA
#
#      sg_orgao_sup_tabela_ug cd_ug_gestora               nm_ug_tabela_ug  \
# 3509               MINIST.         344042  FUNDACAO BIBLIOTECA NACIONAL
#
#      sg_ug_gestora         nr_cnpj nm_unidade_prestacao             sg_orgao  \
# 3509           FBN  39420336000149    FBN - PREDIO SEDE  BIBLIOTECA NACIONAL
#
#                           nm_orgao cd_orgao_siape      cnpj_formatado  \
# 3509  FUNDACAO BIBLIOTECA NACIONAL          24205  39.420.336/0001-49
#
#      id_contrato status_validacao objeto_contrato objeto_compra  \
# 3509         NaN   Não encontrado             NaN           NaN
#
#      dataAssinatura dataPublicacaoDOU dataInicioVigencia dataFimVigencia  \
# 3509            NaN               NaN                NaN             NaN
#
#      tipo_fornecedor valorInicialCompra valorFinalCompra
# ...
